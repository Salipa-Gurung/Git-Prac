# %% [markdown]
# <a href="https://colab.research.google.com/github/Salipa-Gurung/Git-Prac/blob/main/K_mean_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(n_samples=300, centers=5,cluster_std=0.9, random_state=0)

# %%
plt.scatter(X[:, 0], X[:, 1], s=40)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Synthetic Data')
plt.show()

# %%
X

# %%
X[:10]
# Out:
# array([[10.26351111, -1.16294985],
#        [-0.23252112,  8.28186087],
#        [ 0.351159  ,  4.16911624],
#        [ 8.06012233, -3.01658567],
#        [-1.08253641,  2.81338872],
#        [-1.58236778,  2.82130751],
#        [ 1.01470333,  1.60074195],
#        [ 2.00173069,  3.19244409],
#        [ 3.40030361, -0.96532286],
#        [-0.99585824,  6.94164877]])

# %%
X[:5,0]
# Out:
# array([10.26351111, -0.23252112,  0.351159  ,  8.06012233, -1.08253641])

# %%
X[:5,1]
# Out:
# array([-1.16294985,  8.28186087,  4.16911624, -3.01658567,  2.81338872])

# %%
k = 10 #numbers of clusters
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=10)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
plt.scatter(X[:, 0], X[:,1],
            c=labels,
            cmap='viridis',
            s=50)
plt.scatter(centroids[:,0],
            centroids[:,1],
            c='red',
            marker='*',
            s=200)
plt.show()

# %%
inertias = []
for i in range(1,11):
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(X)
  inertias.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,11), inertias)
plt.xlabel("Number of cluster")
plt.ylabel("Inertia")
# Out:
# Text(0, 0.5, 'Inertia')
